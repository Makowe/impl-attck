# %% [markdown]
# # General Setup

# %%
import chipwhisperer as cw
import matplotlib.pyplot as plt
import numpy as np
import shutil
import os
# Out:
# /home/nico/miniconda3/envs/simon/lib/python3.13/site-packages/chipwhisperer/capture/trace/TraceWhisperer.py:31: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources # type: ignore

# %%
rng = np.random.default_rng()

NUM_MEASUREMENTS = 50000

# %%
scope = cw.scope()
target = cw.target(scope, cw.targets.SimpleSerial)
scope.default_setup()
# Out:
# scope.gain.mode                          changed from low                       to high
# scope.gain.gain                          changed from 0                         to 30
# scope.gain.db                            changed from 5.5                       to 24.8359375
# scope.adc.basic_mode                     changed from low                       to rising_edge
# scope.adc.samples                        changed from 24400                     to 5000
# scope.adc.trig_count                     changed from 17499132                  to 93907176
# scope.clock.adc_src                      changed from clkgen_x1                 to clkgen_x4
# scope.clock.adc_freq                     changed from 96000000                  to 29538459
# scope.clock.adc_rate                     changed from 96000000.0                to 29538459.0
# scope.clock.clkgen_div                   changed from 1                         to 26
# scope.clock.clkgen_freq                  changed from 192000000.0               to 7384615.384615385
# scope.io.tio1                            changed from serial_tx                 to serial_rx
# scope.io.tio2                            changed from serial_rx                 to serial_tx
# scope.io.hs2                             changed from None                      to clkgen
# scope.io.cdc_settings                    changed from bytearray(b'\x01\x00\x00\x00') to bytearray(b'\x00\x00\x00\x00')

# %% [markdown]
# # Compile C Code
#
# ## Plain Implementation

# %%
# %%bash
# cd ../chipwhisperer/firmware/mcu/simpleserial-simon/
# make PLATFORM=CWLITEARM CRYPTO_TARGET=SIMON CRYPTO_OPTIONS=NONE
# Out:
# SS_VER set to SS_VER_1_1
# SS_VER set to SS_VER_1_1
# .
# Welcome to another exciting ChipWhisperer target build!!
# arm-none-eabi-gcc (15:13.2.rel1-2) 13.2.1 20231009
# Copyright (C) 2023 Free Software Foundation, Inc.
# This is free software; see the source for copying conditions.  There is NO
# warranty; not even for MERCHANTABILITY or FITNESS FOR A PARTICULAR PURPOSE.
#
# mkdir -p objdir-CWLITEARM
# .
# Compiling:
# -en     simpleserial-simon.c ...
# -e Done!
# .
# Compiling:
# -en     .././simpleserial/simpleserial.c ...
# -e Done!
# .
# Compiling:
# -en     .././hal/hal.c ...
# -e Done!
# .
# Compiling:
# -en     .././hal//stm32f3/stm32f3_hal.c ...
# -e Done!
# .
# Compiling:
# -en     .././hal//stm32f3/stm32f3_hal_lowlevel.c ...
# -e Done!
# .
# Compiling:
# -en     .././hal//stm32f3/stm32f3_sysmem.c ...
# -e Done!
# .
# Compiling:
# -en     .././crypto/simon64_128.c ...
# -e Done!
# .
# Assembling: .././hal//stm32f3/stm32f3_startup.S
# arm-none-eabi-gcc -c -mcpu=cortex-m4 -I. -x assembler-with-cpp -mthumb -mfloat-abi=soft -fmessage-length=0 -ffunction-sections -DF_CPU=7372800 -Wa,-gstabs,-adhlns=objdir-CWLITEARM/stm32f3_startup.lst -I.././simpleserial/ -I.././hal/ -I.././hal/ -I.././hal//stm32f3 -I.././hal//stm32f3/CMSIS -I.././hal//stm32f3/CMSIS/core -I.././hal//stm32f3/CMSIS/device -I.././hal//stm32f4/Legacy -I.././simpleserial/ -I.././crypto/ .././hal//stm32f3/stm32f3_startup.S -o objdir-CWLITEARM/stm32f3_startup.o
# .
# LINKING:
# -en     simpleserial-simon-CWLITEARM.elf ...
# Memory region         Used Size  Region Size  %age Used
#              RAM:        1864 B        40 KB      4.55%
#              ROM:        4972 B       256 KB      1.90%
# -e Done!
# .
# Creating load file for Flash: simpleserial-simon-CWLITEARM.hex
# arm-none-eabi-objcopy -O ihex -R .eeprom -R .fuse -R .lock -R .signature simpleserial-simon-CWLITEARM.elf simpleserial-simon-CWLITEARM.hex
# .
# Creating load file for Flash: simpleserial-simon-CWLITEARM.bin
# arm-none-eabi-objcopy -O binary -R .eeprom -R .fuse -R .lock -R .signature simpleserial-simon-CWLITEARM.elf simpleserial-simon-CWLITEARM.bin
# .
# Creating load file for EEPROM: simpleserial-simon-CWLITEARM.eep
# arm-none-eabi-objcopy -j .eeprom --set-section-flags=.eeprom="alloc,load" \
# --change-section-lma .eeprom=0 --no-change-warnings -O ihex simpleserial-simon-CWLITEARM.elf simpleserial-simon-CWLITEARM.eep || exit 0
# .
# Creating Extended Listing: simpleserial-simon-CWLITEARM.lss
# arm-none-eabi-objdump -h -S -z simpleserial-simon-CWLITEARM.elf > simpleserial-simon-CWLITEARM.lss
# .
# Creating Symbol Table: simpleserial-simon-CWLITEARM.sym
# arm-none-eabi-nm -n simpleserial-simon-CWLITEARM.elf > simpleserial-simon-CWLITEARM.sym
# Size after:
#    text	   data	    bss	    dec	    hex	filename
#    4964	      8	   1864	   6836	   1ab4	simpleserial-simon-CWLITEARM.elf
# +--------------------------------------------------------
# + Default target does full rebuild each time.
# + Specify buildtarget == allquick == to avoid full rebuild
# +--------------------------------------------------------
# +--------------------------------------------------------
# + Built for platform CW-Lite Arm \(STM32F3\) with:
# + CRYPTO_TARGET = SIMON
# + CRYPTO_OPTIONS = NONE
# +--------------------------------------------------------

# %% [markdown]
# ## Masked Implementation

# %%
# %%bash
# cd ../chipwhisperer/firmware/mcu/simpleserial-simon-masked/
# make PLATFORM=CWLITEARM CRYPTO_TARGET=SIMON_MASKED CRYPTO_OPTIONS=NONE
# Out:
# SS_VER set to SS_VER_1_1
# SS_VER set to SS_VER_1_1
# .
# Welcome to another exciting ChipWhisperer target build!!
# arm-none-eabi-gcc (15:13.2.rel1-2) 13.2.1 20231009
# Copyright (C) 2023 Free Software Foundation, Inc.
# This is free software; see the source for copying conditions.  There is NO
# warranty; not even for MERCHANTABILITY or FITNESS FOR A PARTICULAR PURPOSE.
#
# mkdir -p objdir-CWLITEARM
# .
# Compiling:
# -en     simpleserial-simon-masked.c ...
# -e Done!
# .
# Compiling:
# -en     .././simpleserial/simpleserial.c ...
# -e Done!
# .
# Compiling:
# -en     .././hal/hal.c ...
# -e Done!
# .
# Compiling:
# -en     .././hal//stm32f3/stm32f3_hal.c ...
# -e Done!
# .
# Compiling:
# -en     .././hal//stm32f3/stm32f3_hal_lowlevel.c ...
# -e Done!
# .
# Compiling:
# -en     .././hal//stm32f3/stm32f3_sysmem.c ...
# -e Done!
# .
# Compiling:
# -en     .././crypto/simon64_128_masked.c ...
# -e Done!
# .
# Compiling:
# -en     .././crypto/hash-drbg/sha256.c ...
# -e Done!
# .
# Compiling:
# -en     .././crypto/hash-drbg/hdrbg.c ...
# -e Done!
# .
# Compiling:
# -en     .././crypto/hash-drbg/extras.c ...
# -e Done!
# .
# Assembling: .././hal//stm32f3/stm32f3_startup.S
# arm-none-eabi-gcc -c -mcpu=cortex-m4 -I. -x assembler-with-cpp -mthumb -mfloat-abi=soft -fmessage-length=0 -ffunction-sections -DF_CPU=7372800 -Wa,-gstabs,-adhlns=objdir-CWLITEARM/stm32f3_startup.lst -I.././simpleserial/ -I.././hal/ -I.././hal/ -I.././hal//stm32f3 -I.././hal//stm32f3/CMSIS -I.././hal//stm32f3/CMSIS/core -I.././hal//stm32f3/CMSIS/device -I.././hal//stm32f4/Legacy -I.././simpleserial/ -I.././crypto/ -I.././crypto/hash-drbg .././hal//stm32f3/stm32f3_startup.S -o objdir-CWLITEARM/stm32f3_startup.o
# .
# LINKING:
# -en     simpleserial-simon-masked-CWLITEARM.elf ...
# Memory region         Used Size  Region Size  %age Used
#              RAM:        2016 B        40 KB      4.92%
#              ROM:        7068 B       256 KB      2.70%
# -e Done!
# .
# Creating load file for Flash: simpleserial-simon-masked-CWLITEARM.hex
# arm-none-eabi-objcopy -O ihex -R .eeprom -R .fuse -R .lock -R .signature simpleserial-simon-masked-CWLITEARM.elf simpleserial-simon-masked-CWLITEARM.hex
# .
# Creating load file for Flash: simpleserial-simon-masked-CWLITEARM.bin
# arm-none-eabi-objcopy -O binary -R .eeprom -R .fuse -R .lock -R .signature simpleserial-simon-masked-CWLITEARM.elf simpleserial-simon-masked-CWLITEARM.bin
# .
# Creating load file for EEPROM: simpleserial-simon-masked-CWLITEARM.eep
# arm-none-eabi-objcopy -j .eeprom --set-section-flags=.eeprom="alloc,load" \
# --change-section-lma .eeprom=0 --no-change-warnings -O ihex simpleserial-simon-masked-CWLITEARM.elf simpleserial-simon-masked-CWLITEARM.eep || exit 0
# .
# Creating Extended Listing: simpleserial-simon-masked-CWLITEARM.lss
# arm-none-eabi-objdump -h -S -z simpleserial-simon-masked-CWLITEARM.elf > simpleserial-simon-masked-CWLITEARM.lss
# .
# Creating Symbol Table: simpleserial-simon-masked-CWLITEARM.sym
# arm-none-eabi-nm -n simpleserial-simon-masked-CWLITEARM.elf > simpleserial-simon-masked-CWLITEARM.sym
# Size after:
#    text	   data	    bss	    dec	    hex	filename
#    7060	      8	   2016	   9084	   237c	simpleserial-simon-masked-CWLITEARM.elf
# +--------------------------------------------------------
# + Default target does full rebuild each time.
# + Specify buildtarget == allquick == to avoid full rebuild
# +--------------------------------------------------------
# +--------------------------------------------------------
# + Built for platform CW-Lite Arm \(STM32F3\) with:
# + CRYPTO_TARGET = SIMON_MASKED
# + CRYPTO_OPTIONS = NONE
# +--------------------------------------------------------

# %% [markdown]
# # Program Target
#
# ## Plain Implementation

# %%
cw.program_target(scope, cw.programmers.STM32FProgrammer, "../chipwhisperer/firmware/mcu/simpleserial-simon/simpleserial-simon-CWLITEARM.hex")
# Out:
# Detected known STMF32: STM32F302xB(C)/303xB(C)
# Extended erase (0x44), this can take ten seconds or more
# Attempting to program 4971 bytes at 0x8000000
# STM32F Programming flash...
# STM32F Reading flash...
# Verified flash OK, 4971 bytes

# %% [markdown]
# ## Masked Implementation

# %%
# cw.program_target(scope, cw.programmers.STM32FProgrammer, "../chipwhisperer/firmware/mcu/simpleserial-simon-masked/simpleserial-simon-masked-CWLITEARM.hex")
# Out:
# Detected known STMF32: STM32F302xB(C)/303xB(C)
# Extended erase (0x44), this can take ten seconds or more
# Attempting to program 7067 bytes at 0x8000000
# STM32F Programming flash...
# STM32F Reading flash...
# Verified flash OK, 7067 bytes

# %% [markdown]
# # Verify Implementation by using Test Vector

# %%
key = bytearray([0x1B, 0x1A, 0x19, 0x18, 0x13, 0x12, 0x11, 0x10, 0x0B, 0x0A, 0x09, 0x08, 0x03, 0x02, 0x01, 0x00])
pt = bytearray([0x65, 0x6B, 0x69, 0x6C, 0x20, 0x64, 0x6E, 0x75])
ct_expect = bytearray([0x44, 0xC8, 0xFC, 0x20, 0xB9, 0xDF, 0xA0, 0x7A])

target.simpleserial_write('k', key)
target.simpleserial_wait_ack()

target.simpleserial_write('p', pt)
ct: bytearray = target.simpleserial_read('r', 8)

print("Key:                 {}".format(key.hex()))
print("Ciphertext:          {}".format(ct.hex()))
print("Expected Ciphertext: {}".format(ct_expect.hex()))
# Out:
# Key:                 1b1a1918131211100b0a090803020100
# Ciphertext:          44c8fc20b9dfa07a
# Expected Ciphertext: 44c8fc20b9dfa07a

# %% [markdown]
# # Perform Measurements

# %%
if os.path.exists("simon_measurement_leakage_data"):
    shutil.rmtree("simon_measurement_leakage_data")

project = cw.create_project("simon_measurement_leakage", overwrite=True)
key = bytearray([0xad, 0x82, 0x8b, 0xc8, 0x3b, 0xad, 0xa0, 0x7c, 0xc8, 0x0b, 0xf1, 0x2f, 0x75, 0xc0, 0x31, 0x56])
entropy = bytearray(rng.integers(0, 2**32, 12, dtype=np.uint32))
print(key.hex())
print(entropy.hex())
# Out:
# ad828bc83bada07cc80bf12f75c03156
# 30a51803d8050ffff5258e552982932ddb47bb696b1ba4945cff39747644ac2ec121512bc1c5a2ac0b57efd4d4a397ef

# %%
target.output_len = 8

# only enable for masked implementation
# target.simpleserial_write('s', entropy)

pt0 = bytearray(rng.integers(0, 2**32, 2, dtype=np.uint32))

for i in range(NUM_MEASUREMENTS * 2):
    if i % 2 == 0:
        pt = pt0
    else:       
        pt = bytearray(rng.integers(0, 2**32, 2, dtype=np.uint32))

    trace = cw.capture_trace(scope, target, pt, key, as_int=True)
    project.traces.append(trace)

project.save()
project.export("./traces/14_simon_plain_leakage_50000/trace.zip")
# Out:
# '/home/nico/git/impl-attck/simon/traces/14_simon_plain_leakage_50000/trace.zip'

# %%
# %matplotlib widget

plt.figure()
plt.plot(project.traces[0].wave)
plt.plot(project.traces[1].wave)
plt.plot(project.traces[2].wave)
plt.plot(project.traces[3].wave)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
